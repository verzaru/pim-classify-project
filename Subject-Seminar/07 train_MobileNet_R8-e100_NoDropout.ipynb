# %%
import pandas as pd
import numpy as np
import random
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def getTrainData(img_size):
    img_dim = (img_size,img_size)

    train_csv = pd.read_csv('../train.csv')
    train_arr_imgs = [img_to_array(load_img('../train/'+img, target_size=img_dim)) for img in train_csv.image]
    x_train = np.array(train_arr_imgs)

    train_cat = train_csv['category'].values
    y_train = to_categorical(train_cat-1)

    return x_train, y_train

def getTestData(img_size):
    img_dim = (img_size,img_size)

    test_csv = pd.read_csv('../test.csv')
    #test_arr_imgs = [img_to_array(load_img('test/'+img, target_size=img_dim)) for img in test_csv.image]
    test_arr_imgs = []
    for img in test_csv.image:
        img_array = img_to_array(load_img('../test/'+img, target_size=img_dim))
        img_array = img_array/255.0
        test_arr_imgs.append(img_array)
    x_test = np.array(test_arr_imgs)

    test_cat = test_csv.category
    test_cv_y = test_cat-1
    y_test = np.array(test_cv_y)
    return x_test, y_test

# %%
def augData(x_train, y_train, batch_size):
    seed = 42
    random.seed = seed
    np.random.seed(seed=seed)
    train_datagen = ImageDataGenerator(rescale=1./255,  
                                       rotation_range=30,
                                       width_shift_range=0.15,
                                       height_shift_range=0.15,
                                       shear_range=0.2,
                                       zoom_range=0.2,
                                       horizontal_flip=True,
                                       vertical_flip=False,
                                       fill_mode='nearest')
    train_generator = train_datagen.flow(x_train, y_train, batch_size=batch_size, seed=seed)
    return train_generator

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications import MobileNet

IMG_SHAPE = (200, 200, 3)

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
base_model.trainable = False

model = Sequential([
  base_model,
  GlobalAveragePooling2D(),
  Dense(1024,activation='relu'),
  Dense(512,activation='relu'),
  Dense(5, activation='softmax')
])
model.summary()
# Out:
# C:\Users\8FTMA26199\Anaconda3\lib\site-packages\keras_applications\mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Model)   (None, 6, 6, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 4,805,829
# Trainable params: 1,576,965
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
batch_size = 32
x_train, y_train = getTrainData(200)
train_generator = augData(x_train, y_train, batch_size)

# %%
import time
startTime = time.time()

history = model.fit_generator(train_generator,
                              steps_per_epoch=len(x_train) // batch_size,
                              epochs=100)
endTime = time.time()
# Out:
# WARNING:tensorflow:From <ipython-input-7-1f9f4eb2d898>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 78 steps
# Epoch 1/100
# 78/78 [==============================] - 77s 984ms/step - loss: 0.6952 - accuracy: 0.7739
# Epoch 2/100
# 78/78 [==============================] - 56s 712ms/step - loss: 0.3093 - accuracy: 0.8987
# Epoch 3/100
# 78/78 [==============================] - 55s 702ms/step - loss: 0.2179 - accuracy: 0.9335
# Epoch 4/100
# 78/78 [==============================] - 56s 721ms/step - loss: 0.1530 - accuracy: 0.9481
# Epoch 5/100
# 78/78 [==============================] - 55s 699ms/step - loss: 0.2249 - accuracy: 0.9335
# Epoch 6/100
# 78/78 [==============================] - 55s 701ms/step - loss: 0.1587 - accuracy: 0.9449
# Epoch 7/100
# 78/78 [==============================] - 55s 702ms/step - loss: 0.1124 - accuracy: 0.9595
# Epoch 8/100
# 78/78 [==============================] - 55s 700ms/step - loss: 0.1415 - accuracy: 0.9526
# Epoch 9/100
# 78/78 [==============================] - 56s 712ms/step - loss: 0.1433 - accuracy: 0.9510
# Epoch 10/100
# 78/78 [==============================] - 57s 725ms/step - loss: 0.1172 - accuracy: 0.9587
# Epoch 11/100
# 78/78 [==============================] - 55s 701ms/step - loss: 0.1388 - accuracy: 0.9502
# Epoch 12/100
# 78/78 [==============================] - 54s 699ms/step - loss: 0.1062 - accuracy: 0.9643
# Epoch 13/100
# 78/78 [==============================] - 55s 703ms/step - loss: 0.0738 - accuracy: 0.9733
# Epoch 14/100
# 78/78 [==============================] - 55s 700ms/step - loss: 0.0900 - accuracy: 0.9676
# Epoch 15/100
# 78/78 [==============================] - 55s 700ms/step - loss: 0.1207 - accuracy: 0.9583
# Epoch 16/100
# 78/78 [==============================] - 55s 706ms/step - loss: 0.1248 - accuracy: 0.9571
# Epoch 17/100
# 78/78 [==============================] - 55s 700ms/step - loss: 0.1096 - accuracy: 0.9656
# Epoch 18/100
# 78/78 [==============================] - 55s 700ms/step - loss: 0.0883 - accuracy: 0.9749
# Epoch 19/100
# 78/78 [==============================] - 55s 701ms/step - loss: 0.0850 - accuracy: 0.9696
# Epoch 20/100
# 78/78 [==============================] - 55s 703ms/step - loss: 0.0683 - accuracy: 0.9753
# Epoch 21/100
# 78/78 [==============================] - 55s 704ms/step - loss: 0.0650 - accuracy: 0.9801
# Epoch 22/100
# 78/78 [==============================] - 55s 703ms/step - loss: 0.0700 - accuracy: 0.9733
# Epoch 23/100
# 78/78 [==============================] - 55s 703ms/step - loss: 0.0738 - accuracy: 0.9765
# Epoch 24/100
# 78/78 [==============================] - 55s 706ms/step - loss: 0.0586 - accuracy: 0.9785
# Epoch 25/100
# 78/78 [==============================] - 55s 704ms/step - loss: 0.0542 - accuracy: 0.9838
# Epoch 26/100
# 78/78 [==============================] - 56s 717ms/step - loss: 0.0775 - accuracy: 0.9720
# Epoch 27/100
# 78/78 [==============================] - 55s 702ms/step - loss: 0.0668 - accuracy: 0.9769
# Epoch 28/100
# 78/78 [==============================] - 55s 700ms/step - loss: 0.0666 - accuracy: 0.9765
# Epoch 29/100
# 78/78 [==============================] - 55s 708ms/step - loss: 0.0499 - accuracy: 0.9838
# Epoch 30/100
# 78/78 [==============================] - 55s 700ms/step - loss: 0.0516 - accuracy: 0.9793
# Epoch 31/100
# 78/78 [==============================] - 57s 734ms/step - loss: 0.0594 - accuracy: 0.9785
# Epoch 32/100
# 78/78 [==============================] - 61s 787ms/step - loss: 0.0791 - accuracy: 0.9753
# Epoch 33/100
# 78/78 [==============================] - 58s 744ms/step - loss: 0.0597 - accuracy: 0.9814
# Epoch 34/100
# 78/78 [==============================] - 58s 744ms/step - loss: 0.0514 - accuracy: 0.9814
# Epoch 35/100
# 78/78 [==============================] - 59s 762ms/step - loss: 0.0565 - accuracy: 0.9797
# Epoch 36/100
# 78/78 [==============================] - 58s 738ms/step - loss: 0.0580 - accuracy: 0.9789
# Epoch 37/100
# 78/78 [==============================] - 57s 730ms/step - loss: 0.0435 - accuracy: 0.9846
# Epoch 38/100
# 78/78 [==============================] - 58s 744ms/step - loss: 0.0565 - accuracy: 0.9806
# Epoch 39/100
# 78/78 [==============================] - 59s 755ms/step - loss: 0.0466 - accuracy: 0.9834
# Epoch 40/100
# 78/78 [==============================] - 59s 755ms/step - loss: 0.0425 - accuracy: 0.9870
# Epoch 41/100
# 78/78 [==============================] - 58s 748ms/step - loss: 0.0450 - accuracy: 0.9850
# Epoch 42/100
# 78/78 [==============================] - 58s 747ms/step - loss: 0.0380 - accuracy: 0.9862
# Epoch 43/100
# 78/78 [==============================] - 58s 746ms/step - loss: 0.0472 - accuracy: 0.9830
# Epoch 44/100
# 78/78 [==============================] - 58s 738ms/step - loss: 0.0475 - accuracy: 0.9862
# Epoch 45/100
# 78/78 [==============================] - 57s 731ms/step - loss: 0.0411 - accuracy: 0.9854
# Epoch 46/100
# 78/78 [==============================] - 60s 770ms/step - loss: 0.0406 - accuracy: 0.9854
# Epoch 47/100
# 78/78 [==============================] - 58s 748ms/step - loss: 0.0423 - accuracy: 0.9834
# Epoch 48/100
# 78/78 [==============================] - 60s 771ms/step - loss: 0.0478 - accuracy: 0.9838
# Epoch 49/100
# 78/78 [==============================] - 55s 701ms/step - loss: 0.0445 - accuracy: 0.9854
# Epoch 50/100
# 78/78 [==============================] - 55s 711ms/step - loss: 0.0836 - accuracy: 0.9729
# Epoch 51/100
# 78/78 [==============================] - 55s 701ms/step - loss: 0.0524 - accuracy: 0.9842
# Epoch 52/100
# 78/78 [==============================] - 59s 751ms/step - loss: 0.0362 - accuracy: 0.9882
# Epoch 53/100
# 78/78 [==============================] - 62s 794ms/step - loss: 0.0470 - accuracy: 0.9838
# Epoch 54/100
# 78/78 [==============================] - 61s 786ms/step - loss: 0.0296 - accuracy: 0.9903
# Epoch 55/100
# 78/78 [==============================] - 61s 778ms/step - loss: 0.0313 - accuracy: 0.9887
# Epoch 56/100
# 78/78 [==============================] - 62s 791ms/step - loss: 0.0455 - accuracy: 0.9846
# Epoch 57/100
# 78/78 [==============================] - 60s 773ms/step - loss: 0.0557 - accuracy: 0.9822
# Epoch 58/100
# 78/78 [==============================] - 60s 769ms/step - loss: 0.0429 - accuracy: 0.9887
# Epoch 59/100
# 78/78 [==============================] - 59s 750ms/step - loss: 0.0483 - accuracy: 0.9846
# Epoch 60/100
# 78/78 [==============================] - 61s 781ms/step - loss: 0.0331 - accuracy: 0.9874
# Epoch 61/100
# 78/78 [==============================] - 58s 738ms/step - loss: 0.0339 - accuracy: 0.9874
# Epoch 62/100
# 78/78 [==============================] - 58s 747ms/step - loss: 0.0378 - accuracy: 0.9891
# Epoch 63/100
# 78/78 [==============================] - 62s 795ms/step - loss: 0.0306 - accuracy: 0.9895
# Epoch 64/100
# 78/78 [==============================] - 59s 755ms/step - loss: 0.0565 - accuracy: 0.9826
# Epoch 65/100
# 78/78 [==============================] - 59s 753ms/step - loss: 0.0251 - accuracy: 0.9911
# Epoch 66/100
# 78/78 [==============================] - 59s 754ms/step - loss: 0.0207 - accuracy: 0.9943
# Epoch 67/100
# 78/78 [==============================] - 58s 741ms/step - loss: 0.0431 - accuracy: 0.9870
# Epoch 68/100
# 78/78 [==============================] - 62s 791ms/step - loss: 0.0739 - accuracy: 0.9773
# Epoch 69/100
# 78/78 [==============================] - 61s 782ms/step - loss: 0.0383 - accuracy: 0.9838
# Epoch 70/100
# 78/78 [==============================] - 58s 739ms/step - loss: 0.0226 - accuracy: 0.9927
# Epoch 71/100
# 78/78 [==============================] - 61s 786ms/step - loss: 0.0393 - accuracy: 0.9866
# Epoch 72/100
# 78/78 [==============================] - 64s 821ms/step - loss: 0.0350 - accuracy: 0.9882
# Epoch 73/100
# 78/78 [==============================] - 60s 771ms/step - loss: 0.0462 - accuracy: 0.9842
# Epoch 74/100
# 78/78 [==============================] - 66s 843ms/step - loss: 0.0332 - accuracy: 0.9882
# Epoch 75/100
# 78/78 [==============================] - 61s 786ms/step - loss: 0.0350 - accuracy: 0.9862
# Epoch 76/100
# 78/78 [==============================] - 57s 734ms/step - loss: 0.0205 - accuracy: 0.9923
# Epoch 77/100
# 78/78 [==============================] - 63s 810ms/step - loss: 0.0337 - accuracy: 0.9862
# Epoch 78/100
# 78/78 [==============================] - 55s 711ms/step - loss: 0.0359 - accuracy: 0.9878
# Epoch 79/100
# 78/78 [==============================] - 61s 781ms/step - loss: 0.0326 - accuracy: 0.9882
# Epoch 80/100
# 78/78 [==============================] - 61s 787ms/step - loss: 0.0270 - accuracy: 0.9895
# Epoch 81/100
# 78/78 [==============================] - 59s 751ms/step - loss: 0.0365 - accuracy: 0.9868
# Epoch 82/100
# 78/78 [==============================] - 59s 755ms/step - loss: 0.0375 - accuracy: 0.9862
# Epoch 83/100
# 78/78 [==============================] - 61s 777ms/step - loss: 0.0373 - accuracy: 0.9866
# Epoch 84/100
# 78/78 [==============================] - 60s 763ms/step - loss: 0.0260 - accuracy: 0.9907
# Epoch 85/100
# 78/78 [==============================] - 60s 771ms/step - loss: 0.0303 - accuracy: 0.9878
# Epoch 86/100
# 78/78 [==============================] - 59s 762ms/step - loss: 0.0352 - accuracy: 0.9903
# Epoch 87/100
# 78/78 [==============================] - 63s 803ms/step - loss: 0.0577 - accuracy: 0.9834
# Epoch 88/100
# 78/78 [==============================] - 62s 795ms/step - loss: 0.0357 - accuracy: 0.9858
# Epoch 89/100
# 78/78 [==============================] - 60s 775ms/step - loss: 0.0311 - accuracy: 0.9899
# Epoch 90/100
# 78/78 [==============================] - 65s 829ms/step - loss: 0.0279 - accuracy: 0.9895
# Epoch 91/100
# 78/78 [==============================] - 58s 745ms/step - loss: 0.0309 - accuracy: 0.9891
# Epoch 92/100
# 78/78 [==============================] - 62s 798ms/step - loss: 0.0253 - accuracy: 0.9931
# Epoch 93/100
# 78/78 [==============================] - 60s 768ms/step - loss: 0.0216 - accuracy: 0.9927
# Epoch 94/100
# 78/78 [==============================] - 66s 848ms/step - loss: 0.0365 - accuracy: 0.9891
# Epoch 95/100
# 78/78 [==============================] - 60s 769ms/step - loss: 0.0275 - accuracy: 0.9927
# Epoch 96/100
# 78/78 [==============================] - 64s 815ms/step - loss: 0.0400 - accuracy: 0.9870
# Epoch 97/100
# 78/78 [==============================] - 59s 755ms/step - loss: 0.0231 - accuracy: 0.9915
# Epoch 98/100
# 78/78 [==============================] - 61s 777ms/step - loss: 0.0153 - accuracy: 0.9959
# Epoch 99/100
# 78/78 [==============================] - 58s 738ms/step - loss: 0.0240 - accuracy: 0.9919
# Epoch 100/100
# 78/78 [==============================] - 56s 718ms/step - loss: 0.0298 - accuracy: 0.9907

# %%
name = 'MobileNet_R8-e100_NoDropout'
model_name = 'Mobile Net'

# %%
def saveH5(model,name):
    model.save_weights(name+'_model-save-wieghts.h5')
    model.save(name+'_model-save.h5')
saveH5(model,name)

# %%
def saveHistory(history, name):
    hist_df = pd.DataFrame(history.history) 
    hist_json_file = name+'_history.json' 
    with open(hist_json_file, mode='w') as f:
        hist_df.to_json(f)
    hist_csv_file = name+'_history.csv'
    with open(hist_csv_file, mode='w') as f:
        hist_df.to_csv(f)
saveHistory(history,name)

# %%
def printTime(startTime, endTime):
    print("Strat time = "+str(startTime))
    print("End time = "+str(endTime))
    print("Use time = "+str(endTime-startTime))
printTime(startTime, endTime)
# Out:
# Strat time = 1588255788.6754284
# End time = 1588261634.6238935
# Use time = 5845.9484651088715

# %%
def plotAccuracyLoss(history):
    acc = history.history['accuracy']
    loss = history.history['loss']
    epochs = range(1, len(acc) + 1)

    #Train and validation accuracy
    plt.style.use('default')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    #plt.yticks(np.arange(0, 1))
    plt.plot(epochs, acc, 'b', label='Training Accurarcy')
    plt.title('Training Accuracy ('+model_name+')')
    plt.legend()
    plt.grid(True)
    plt.figure()
    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    plt.title('Training Loss ('+model_name+')')
    plt.legend()
    plt.show()
plotAccuracyLoss(history)

# %%
def plotBothAccuracyLoss(history):
    acc = history.history['accuracy']
    loss = history.history['loss']
    epochs = range(1, len(acc) + 1)

    #Train and validation accuracy
    plt.style.use('default')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    #plt.yticks(np.arange(0, 1))
    plt.plot(epochs, acc, 'b', label='Training Accurarcy')
    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    plt.title('Training Accuracy and Loss ('+model_name+')')
    plt.legend()
    plt.show()
plotBothAccuracyLoss(history)

# %%
x_test, y_test = getTestData(200)

# %%
y_pred = model.predict(x_test)

# %%
def convertPred1D(y_pred):
    get_argmax = []
    for i in range(len(y_pred)):
        get_argmax.append(np.argmax(y_pred[i]))
    return get_argmax
y_pred1d = convertPred1D(y_pred)

# %%
def savePrediction(pred, name):
    test_csv = pd.read_csv('../test.csv')
    test_dict = {'image': test_csv.image, 'y_true': test_csv.category-1, 'y_pred': pred}
    df_pred = pd.DataFrame(test_dict)
    export_pred = df_pred.to_csv(r''+name+'_y-prediction.csv', index = None, header=True)
savePrediction(y_pred1d, name)

# %%
def plotConfusionMatrix(array, name):
    df_cm = pd.DataFrame(array, index = ['Cargo', 'Military', 'Carrier', 'Cruise', 'Tankers'], columns = ['Cargo', 'Military', 'Carrier', 'Cruise', 'Tankers'])
    plt.figure()
    sn.heatmap(df_cm, annot=True, cmap="Blues")
    plt.title('Confusion Matrix ('+name+')',fontsize = 15)
    plt.show()
plotConfusionMatrix(confusion_matrix(y_test, y_pred1d),model_name)

# %%
confusion_matrix(y_test, y_pred1d)
# Out:
# array([[82,  3,  0,  1, 14],
#        [ 0, 97,  0,  2,  1],
#        [ 1,  3, 91,  2,  3],
#        [ 0,  1,  0, 99,  0],
#        [ 2,  3,  2,  2, 91]], dtype=int64)

# %%
def printReport(y_test, y_pred, name):
    print(classification_report(y_test, y_pred))
    report = classification_report(y_test, y_pred, output_dict=True)
    df_rp = pd.DataFrame(report).transpose()
    export_rp = df_rp.to_csv(r''+name+'_cls-report.csv', index = None, header=True)
printReport(y_test, y_pred1d, name)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89       100
#            1       0.91      0.97      0.94       100
#            2       0.98      0.91      0.94       100
#            3       0.93      0.99      0.96       100
#            4       0.83      0.91      0.87       100
#
#     accuracy                           0.92       500
#    macro avg       0.92      0.92      0.92       500
# weighted avg       0.92      0.92      0.92       500
