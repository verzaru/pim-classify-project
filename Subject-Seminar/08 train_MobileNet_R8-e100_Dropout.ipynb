# %%
import pandas as pd
import numpy as np
import random
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def getTrainData(img_size):
    img_dim = (img_size,img_size)

    train_csv = pd.read_csv('../train.csv')
    train_arr_imgs = [img_to_array(load_img('../train/'+img, target_size=img_dim)) for img in train_csv.image]
    x_train = np.array(train_arr_imgs)

    train_cat = train_csv['category'].values
    y_train = to_categorical(train_cat-1)

    return x_train, y_train

def getTestData(img_size):
    img_dim = (img_size,img_size)

    test_csv = pd.read_csv('../test.csv')
    #test_arr_imgs = [img_to_array(load_img('test/'+img, target_size=img_dim)) for img in test_csv.image]
    test_arr_imgs = []
    for img in test_csv.image:
        img_array = img_to_array(load_img('../test/'+img, target_size=img_dim))
        img_array = img_array/255.0
        test_arr_imgs.append(img_array)
    x_test = np.array(test_arr_imgs)

    test_cat = test_csv.category
    test_cv_y = test_cat-1
    y_test = np.array(test_cv_y)
    return x_test, y_test

# %%
def augData(x_train, y_train, batch_size):
    seed = 42
    random.seed = seed
    np.random.seed(seed=seed)
    train_datagen = ImageDataGenerator(rescale=1./255,  
                                       rotation_range=30,
                                       width_shift_range=0.15,
                                       height_shift_range=0.15,
                                       shear_range=0.2,
                                       zoom_range=0.2,
                                       horizontal_flip=True,
                                       vertical_flip=False,
                                       fill_mode='nearest')
    train_generator = train_datagen.flow(x_train, y_train, batch_size=batch_size, seed=seed)
    return train_generator

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications import MobileNet

IMG_SHAPE = (200, 200, 3)

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
base_model.trainable = False

model = Sequential([
  base_model,
  GlobalAveragePooling2D(),
  Dense(1024,activation='relu'),
  Dropout(rate=0.5),
  Dense(512,activation='relu'),
  Dropout(rate=0.5),
  Dense(5, activation='softmax')
])
model.summary()
# Out:
# C:\Users\8FTMA26199\Anaconda3\lib\site-packages\keras_applications\mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Model)   (None, 6, 6, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 4,805,829
# Trainable params: 1,576,965
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
batch_size = 32
x_train, y_train = getTrainData(200)
train_generator = augData(x_train, y_train, batch_size)

# %%
import time
startTime = time.time()

history = model.fit_generator(train_generator,
                              steps_per_epoch=len(x_train) // batch_size,
                              epochs=100)
endTime = time.time()
# Out:
# WARNING:tensorflow:From <ipython-input-7-1f9f4eb2d898>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 78 steps
# Epoch 1/100
# 78/78 [==============================] - 63s 811ms/step - loss: 0.9240 - accuracy: 0.6775
# Epoch 2/100
# 78/78 [==============================] - 67s 853ms/step - loss: 0.3563 - accuracy: 0.8744
# Epoch 3/100
# 78/78 [==============================] - 58s 744ms/step - loss: 0.3037 - accuracy: 0.9015
# Epoch 4/100
# 78/78 [==============================] - 59s 753ms/step - loss: 0.3266 - accuracy: 0.8942
# Epoch 5/100
# 78/78 [==============================] - 56s 712ms/step - loss: 0.2760 - accuracy: 0.9052
# Epoch 6/100
# 78/78 [==============================] - 56s 713ms/step - loss: 0.2288 - accuracy: 0.9303
# Epoch 7/100
# 78/78 [==============================] - 56s 714ms/step - loss: 0.2557 - accuracy: 0.9202
# Epoch 8/100
# 78/78 [==============================] - 56s 715ms/step - loss: 0.2079 - accuracy: 0.9283
# Epoch 9/100
# 78/78 [==============================] - 58s 741ms/step - loss: 0.2049 - accuracy: 0.9344
# Epoch 10/100
# 78/78 [==============================] - 57s 727ms/step - loss: 0.2231 - accuracy: 0.9267
# Epoch 11/100
# 78/78 [==============================] - 56s 716ms/step - loss: 0.1832 - accuracy: 0.9417
# Epoch 12/100
# 78/78 [==============================] - 60s 770ms/step - loss: 0.1817 - accuracy: 0.9331
# Epoch 13/100
# 78/78 [==============================] - 61s 787ms/step - loss: 0.1713 - accuracy: 0.9412
# Epoch 14/100
# 78/78 [==============================] - 66s 848ms/step - loss: 0.1878 - accuracy: 0.9392
# Epoch 15/100
# 78/78 [==============================] - 68s 877ms/step - loss: 0.1694 - accuracy: 0.9404
# Epoch 16/100
# 78/78 [==============================] - 59s 752ms/step - loss: 0.1712 - accuracy: 0.9465
# Epoch 17/100
# 78/78 [==============================] - 64s 823ms/step - loss: 0.1473 - accuracy: 0.9526
# Epoch 18/100
# 78/78 [==============================] - 59s 758ms/step - loss: 0.1541 - accuracy: 0.9522
# Epoch 19/100
# 78/78 [==============================] - 59s 759ms/step - loss: 0.1468 - accuracy: 0.9571
# Epoch 20/100
# 78/78 [==============================] - 58s 738ms/step - loss: 0.1531 - accuracy: 0.9481
# Epoch 21/100
# 78/78 [==============================] - 58s 741ms/step - loss: 0.1767 - accuracy: 0.9408
# Epoch 22/100
# 78/78 [==============================] - 59s 757ms/step - loss: 0.1519 - accuracy: 0.9554
# Epoch 23/100
# 78/78 [==============================] - 60s 763ms/step - loss: 0.2038 - accuracy: 0.9307
# Epoch 24/100
# 78/78 [==============================] - 61s 780ms/step - loss: 0.1384 - accuracy: 0.9522
# Epoch 25/100
# 78/78 [==============================] - 60s 775ms/step - loss: 0.1370 - accuracy: 0.9538
# Epoch 26/100
# 78/78 [==============================] - 61s 779ms/step - loss: 0.1334 - accuracy: 0.9595
# Epoch 27/100
# 78/78 [==============================] - 57s 735ms/step - loss: 0.1391 - accuracy: 0.9534
# Epoch 28/100
# 78/78 [==============================] - 61s 788ms/step - loss: 0.1040 - accuracy: 0.9656
# Epoch 29/100
# 78/78 [==============================] - 60s 764ms/step - loss: 0.1577 - accuracy: 0.9494
# Epoch 30/100
# 78/78 [==============================] - 58s 742ms/step - loss: 0.1195 - accuracy: 0.9599
# Epoch 31/100
# 78/78 [==============================] - 60s 775ms/step - loss: 0.1412 - accuracy: 0.9554
# Epoch 32/100
# 78/78 [==============================] - 58s 744ms/step - loss: 0.1215 - accuracy: 0.9575
# Epoch 33/100
# 78/78 [==============================] - 60s 765ms/step - loss: 0.0959 - accuracy: 0.9684
# Epoch 34/100
# 78/78 [==============================] - 63s 802ms/step - loss: 0.1057 - accuracy: 0.9635
# Epoch 35/100
# 78/78 [==============================] - 59s 756ms/step - loss: 0.0860 - accuracy: 0.9692
# Epoch 36/100
# 78/78 [==============================] - 60s 765ms/step - loss: 0.1302 - accuracy: 0.9595
# Epoch 37/100
# 78/78 [==============================] - 59s 754ms/step - loss: 0.1110 - accuracy: 0.9643
# Epoch 38/100
# 78/78 [==============================] - 62s 795ms/step - loss: 0.1104 - accuracy: 0.9603
# Epoch 39/100
# 78/78 [==============================] - 60s 775ms/step - loss: 0.1308 - accuracy: 0.9562
# Epoch 40/100
# 78/78 [==============================] - 63s 804ms/step - loss: 0.1042 - accuracy: 0.9672
# Epoch 41/100
# 78/78 [==============================] - 58s 745ms/step - loss: 0.1339 - accuracy: 0.9571
# Epoch 42/100
# 78/78 [==============================] - 58s 743ms/step - loss: 0.1638 - accuracy: 0.9522
# Epoch 43/100
# 78/78 [==============================] - 59s 751ms/step - loss: 0.1452 - accuracy: 0.9522
# Epoch 44/100
# 78/78 [==============================] - 62s 790ms/step - loss: 0.1287 - accuracy: 0.9571
# Epoch 45/100
# 78/78 [==============================] - 62s 793ms/step - loss: 0.0768 - accuracy: 0.9716
# Epoch 46/100
# 78/78 [==============================] - 58s 743ms/step - loss: 0.1187 - accuracy: 0.9668
# Epoch 47/100
# 78/78 [==============================] - 60s 769ms/step - loss: 0.1187 - accuracy: 0.9579
# Epoch 48/100
# 78/78 [==============================] - 60s 764ms/step - loss: 0.1079 - accuracy: 0.9635
# Epoch 49/100
# 78/78 [==============================] - 63s 811ms/step - loss: 0.1127 - accuracy: 0.9635
# Epoch 50/100
# 78/78 [==============================] - 62s 792ms/step - loss: 0.0931 - accuracy: 0.9672
# Epoch 51/100
# 78/78 [==============================] - 67s 856ms/step - loss: 0.0797 - accuracy: 0.9716
# Epoch 52/100
# 78/78 [==============================] - 60s 773ms/step - loss: 0.0979 - accuracy: 0.9737
# Epoch 53/100
# 78/78 [==============================] - 57s 734ms/step - loss: 0.0864 - accuracy: 0.9704
# Epoch 54/100
# 78/78 [==============================] - 61s 785ms/step - loss: 0.1154 - accuracy: 0.9639
# Epoch 55/100
# 78/78 [==============================] - 61s 778ms/step - loss: 0.1071 - accuracy: 0.9700
# Epoch 56/100
# 78/78 [==============================] - 62s 790ms/step - loss: 0.0955 - accuracy: 0.9737
# Epoch 57/100
# 78/78 [==============================] - 62s 791ms/step - loss: 0.1207 - accuracy: 0.9619
# Epoch 58/100
# 78/78 [==============================] - 62s 798ms/step - loss: 0.1751 - accuracy: 0.9575
# Epoch 59/100
# 78/78 [==============================] - 64s 823ms/step - loss: 0.1245 - accuracy: 0.9575
# Epoch 60/100
# 78/78 [==============================] - 64s 821ms/step - loss: 0.1066 - accuracy: 0.9660
# Epoch 61/100
# 78/78 [==============================] - 61s 777ms/step - loss: 0.0872 - accuracy: 0.9745
# Epoch 62/100
# 78/78 [==============================] - 60s 770ms/step - loss: 0.0816 - accuracy: 0.9729
# Epoch 63/100
# 78/78 [==============================] - 56s 719ms/step - loss: 0.1011 - accuracy: 0.9676
# Epoch 64/100
# 78/78 [==============================] - 56s 719ms/step - loss: 0.1269 - accuracy: 0.9591
# Epoch 65/100
# 78/78 [==============================] - 60s 772ms/step - loss: 0.1051 - accuracy: 0.9676
# Epoch 66/100
# 78/78 [==============================] - 59s 760ms/step - loss: 0.0967 - accuracy: 0.9688
# Epoch 67/100
# 78/78 [==============================] - 62s 792ms/step - loss: 0.1171 - accuracy: 0.9599
# Epoch 68/100
# 78/78 [==============================] - 62s 795ms/step - loss: 0.0936 - accuracy: 0.9688
# Epoch 69/100
# 78/78 [==============================] - 60s 773ms/step - loss: 0.0977 - accuracy: 0.9664
# Epoch 70/100
# 78/78 [==============================] - 66s 849ms/step - loss: 0.1118 - accuracy: 0.9635
# Epoch 71/100
# 78/78 [==============================] - 63s 811ms/step - loss: 0.0905 - accuracy: 0.9700
# Epoch 72/100
# 78/78 [==============================] - 61s 780ms/step - loss: 0.0784 - accuracy: 0.9724
# Epoch 73/100
# 78/78 [==============================] - 58s 746ms/step - loss: 0.0867 - accuracy: 0.9708
# Epoch 74/100
# 78/78 [==============================] - 60s 764ms/step - loss: 0.1300 - accuracy: 0.9647
# Epoch 75/100
# 78/78 [==============================] - 62s 801ms/step - loss: 0.0988 - accuracy: 0.9684
# Epoch 76/100
# 78/78 [==============================] - 59s 758ms/step - loss: 0.0867 - accuracy: 0.9708
# Epoch 77/100
# 78/78 [==============================] - 63s 808ms/step - loss: 0.0986 - accuracy: 0.9708
# Epoch 78/100
# 78/78 [==============================] - 58s 744ms/step - loss: 0.1016 - accuracy: 0.9656
# Epoch 79/100
# 78/78 [==============================] - 59s 761ms/step - loss: 0.0646 - accuracy: 0.9810
# Epoch 80/100
# 78/78 [==============================] - 61s 777ms/step - loss: 0.0977 - accuracy: 0.9647
# Epoch 81/100
# 78/78 [==============================] - 58s 746ms/step - loss: 0.0820 - accuracy: 0.9716
# Epoch 82/100
# 78/78 [==============================] - 60s 773ms/step - loss: 0.0749 - accuracy: 0.9769
# Epoch 83/100
# 78/78 [==============================] - 66s 850ms/step - loss: 0.0984 - accuracy: 0.9704
# Epoch 84/100
# 78/78 [==============================] - 65s 830ms/step - loss: 0.0796 - accuracy: 0.9745
# Epoch 85/100
# 78/78 [==============================] - 62s 789ms/step - loss: 0.0927 - accuracy: 0.9720
# Epoch 86/100
# 78/78 [==============================] - 58s 746ms/step - loss: 0.0978 - accuracy: 0.9724
# Epoch 87/100
# 78/78 [==============================] - 65s 834ms/step - loss: 0.0913 - accuracy: 0.9729
# Epoch 88/100
# 78/78 [==============================] - 61s 783ms/step - loss: 0.0826 - accuracy: 0.9781
# Epoch 89/100
# 78/78 [==============================] - 64s 816ms/step - loss: 0.0953 - accuracy: 0.9692
# Epoch 90/100
# 78/78 [==============================] - 64s 826ms/step - loss: 0.0847 - accuracy: 0.9761
# Epoch 91/100
# 78/78 [==============================] - 63s 812ms/step - loss: 0.0954 - accuracy: 0.9776
# Epoch 92/100
# 78/78 [==============================] - 64s 818ms/step - loss: 0.0730 - accuracy: 0.9720
# Epoch 93/100
# 78/78 [==============================] - 56s 715ms/step - loss: 0.0786 - accuracy: 0.9765
# Epoch 94/100
# 78/78 [==============================] - 61s 785ms/step - loss: 0.0974 - accuracy: 0.9684
# Epoch 95/100
# 78/78 [==============================] - 64s 821ms/step - loss: 0.0726 - accuracy: 0.9741
# Epoch 96/100
# 78/78 [==============================] - 61s 780ms/step - loss: 0.0810 - accuracy: 0.9724
# Epoch 97/100
# 78/78 [==============================] - 61s 776ms/step - loss: 0.0925 - accuracy: 0.9724
# Epoch 98/100
# 78/78 [==============================] - 59s 757ms/step - loss: 0.0963 - accuracy: 0.9680
# Epoch 99/100
# 78/78 [==============================] - 59s 754ms/step - loss: 0.1089 - accuracy: 0.9712
# Epoch 100/100
# 78/78 [==============================] - 58s 750ms/step - loss: 0.0693 - accuracy: 0.9785

# %%
name = 'MobileNet_R8-e100_NoDropout'
model_name = 'Mobile Net'

# %%
def saveH5(model,name):
    model.save_weights(name+'_model-save-wieghts.h5')
    model.save(name+'_model-save.h5')
saveH5(model,name)

# %%
def saveHistory(history, name):
    hist_df = pd.DataFrame(history.history) 
    hist_json_file = name+'_history.json' 
    with open(hist_json_file, mode='w') as f:
        hist_df.to_json(f)
    hist_csv_file = name+'_history.csv'
    with open(hist_csv_file, mode='w') as f:
        hist_df.to_csv(f)
saveHistory(history,name)

# %%
def printTime(startTime, endTime):
    print("Strat time = "+str(startTime))
    print("End time = "+str(endTime))
    print("Use time = "+str(endTime-startTime))
printTime(startTime, endTime)
# Out:
# Strat time = 1588225352.7703562
# End time = 1588231402.565152
# Use time = 6049.794795751572

# %%
def plotAccuracyLoss(history):
    acc = history.history['accuracy']
    loss = history.history['loss']
    epochs = range(1, len(acc) + 1)

    #Train and validation accuracy
    plt.style.use('default')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    #plt.yticks(np.arange(0, 1))
    plt.plot(epochs, acc, 'b', label='Training Accurarcy')
    plt.title('Training Accuracy ('+model_name+')')
    plt.legend()
    plt.grid(True)
    plt.figure()
    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    plt.title('Training Loss ('+model_name+')')
    plt.legend()
    plt.show()
plotAccuracyLoss(history)

# %%
def plotBothAccuracyLoss(history):
    acc = history.history['accuracy']
    loss = history.history['loss']
    epochs = range(1, len(acc) + 1)

    #Train and validation accuracy
    plt.style.use('default')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    #plt.yticks(np.arange(0, 1))
    plt.plot(epochs, acc, 'b', label='Training Accurarcy')
    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.grid(True)
    plt.xticks(np.arange(0, len(acc)+1, 1.0))
    plt.title('Training Accuracy and Loss ('+model_name+')')
    plt.legend()
    plt.show()
plotBothAccuracyLoss(history)

# %%
x_test, y_test = getTestData(200)

# %%
y_pred = model.predict(x_test)

# %%
def convertPred1D(y_pred):
    get_argmax = []
    for i in range(len(y_pred)):
        get_argmax.append(np.argmax(y_pred[i]))
    return get_argmax
y_pred1d = convertPred1D(y_pred)

# %%
def savePrediction(pred, name):
    test_csv = pd.read_csv('../test.csv')
    test_dict = {'image': test_csv.image, 'y_true': test_csv.category-1, 'y_pred': pred}
    df_pred = pd.DataFrame(test_dict)
    export_pred = df_pred.to_csv(r''+name+'_y-prediction.csv', index = None, header=True)
savePrediction(y_pred1d, name)

# %%
def plotConfusionMatrix(array, name):
    df_cm = pd.DataFrame(array, index = ['Cargo', 'Military', 'Carrier', 'Cruise', 'Tankers'], columns = ['Cargo', 'Military', 'Carrier', 'Cruise', 'Tankers'])
    plt.figure()
    sn.heatmap(df_cm, annot=True, cmap="Blues")
    plt.title('Confusion Matrix ('+name+')',fontsize = 15)
    plt.show()
plotConfusionMatrix(confusion_matrix(y_test, y_pred1d),model_name)

# %%
confusion_matrix(y_test, y_pred1d)
# Out:
# array([[78,  4,  1,  0, 17],
#        [ 0, 97,  1,  0,  2],
#        [ 0,  1, 96,  0,  3],
#        [ 0,  1,  1, 97,  1],
#        [ 0,  3,  0,  0, 97]], dtype=int64)

# %%
def printReport(y_test, y_pred, name):
    print(classification_report(y_test, y_pred))
    report = classification_report(y_test, y_pred, output_dict=True)
    df_rp = pd.DataFrame(report).transpose()
    export_rp = df_rp.to_csv(r''+name+'_cls-report.csv', index = None, header=True)
printReport(y_test, y_pred1d, name)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88       100
#            1       0.92      0.97      0.94       100
#            2       0.97      0.96      0.96       100
#            3       1.00      0.97      0.98       100
#            4       0.81      0.97      0.88       100
#
#     accuracy                           0.93       500
#    macro avg       0.94      0.93      0.93       500
# weighted avg       0.94      0.93      0.93       500
