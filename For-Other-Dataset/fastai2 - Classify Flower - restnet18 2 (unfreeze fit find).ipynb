# %%
from fastai.vision.all import *
from fastai.metrics import error_rate, accuracy

# %%
path = Path('C:/Users/NCC/Desktop/thesis/dataset/flowers')

# %%
tfms = aug_transforms(do_flip = True, 
                      flip_vert = False, 
                      mult=2.0)

dls = ImageDataLoaders.from_folder(path, 
                                   valid_pct=0.2, 
                                   seed=42, 
                                   item_tfms=Resize(128), 
                                   batch_tfms=tfms, 
                                   num_workers=0)

# %%
dls.valid_ds.items[:3]
# Out:
# [Path('C:/Users/NCC/Desktop/thesis/dataset/flowers/dandelion/7448453384_fb9caaa9af_n.jpg'),
#  Path('C:/Users/NCC/Desktop/thesis/dataset/flowers/tulip/19695087459_dfb18ea181_n.jpg'),
#  Path('C:/Users/NCC/Desktop/thesis/dataset/flowers/rose/5336562502_d697a3f0b2_n.jpg')]

# %%
print("Number of classes: ", dls.c)
# Out:
# Number of classes:  5

# %%
dls.show_batch()

# %%
learn = cnn_learner(dls, resnet18, normalize=True, pretrained=True, metrics=[error_rate, accuracy])

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.010000000149011612, lr_steep=7.585775847473997e-07)

# %%
print("Optimizer...")
learn.recorder.opt_func
# Out:
# Optimizer...
# <function fastai.optimizer.Adam(params, lr, mom=0.9, sqr_mom=0.99, eps=1e-05, wd=0.01, decouple_wd=True)>

# %%
print("Loss Function...")
learn.recorder.loss_func
# Out:
# Loss Function...
# FlattenedLoss of CrossEntropyLoss()

# %%
lr = 0.012022644281387329
learn.fit_one_cycle(10,lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.080850</td>
#       <td>0.582355</td>
#       <td>0.174769</td>
#       <td>0.825231</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.762993</td>
#       <td>0.506632</td>
#       <td>0.181713</td>
#       <td>0.818287</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.706931</td>
#       <td>0.501361</td>
#       <td>0.175926</td>
#       <td>0.824074</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.621504</td>
#       <td>0.544017</td>
#       <td>0.166667</td>
#       <td>0.833333</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.543427</td>
#       <td>0.373667</td>
#       <td>0.131944</td>
#       <td>0.868056</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.468115</td>
#       <td>0.334415</td>
#       <td>0.113426</td>
#       <td>0.886574</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.417243</td>
#       <td>0.277551</td>
#       <td>0.100694</td>
#       <td>0.899306</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.376851</td>
#       <td>0.326487</td>
#       <td>0.111111</td>
#       <td>0.888889</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.323465</td>
#       <td>0.271915</td>
#       <td>0.099537</td>
#       <td>0.900463</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.296867</td>
#       <td>0.284017</td>
#       <td>0.101852</td>
#       <td>0.898148</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('flowers-resnet18-s1-v2')
# Out:
# Path('C:/Users/NCC/Desktop/thesis/dataset/flowers/models/flowers-resnet18-s1-v2.pth')

# %%
learn.recorder.plot_loss()

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9)

# %%
interp.plot_confusion_matrix(title='Confusion matrix')

# %%
interp.print_classification_report()
# Out:
#               precision    recall  f1-score   support
#
#        daisy       0.95      0.86      0.90       163
#    dandelion       0.92      0.93      0.92       198
#         rose       0.80      0.98      0.88       162
#    sunflower       0.92      0.94      0.93       146
#        tulip       0.92      0.81      0.86       195
#
#     accuracy                           0.90       864
#    macro avg       0.90      0.90      0.90       864
# weighted avg       0.90      0.90      0.90       864

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.334368</td>
#       <td>0.366809</td>
#       <td>0.121528</td>
#       <td>0.878472</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.482984</td>
#       <td>0.969114</td>
#       <td>0.258102</td>
#       <td>0.741898</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.540892</td>
#       <td>0.472046</td>
#       <td>0.170139</td>
#       <td>0.829861</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.463351</td>
#       <td>0.629571</td>
#       <td>0.202546</td>
#       <td>0.797454</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.410605</td>
#       <td>0.391385</td>
#       <td>0.143519</td>
#       <td>0.856481</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.357676</td>
#       <td>0.326859</td>
#       <td>0.113426</td>
#       <td>0.886574</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.319087</td>
#       <td>0.278229</td>
#       <td>0.094907</td>
#       <td>0.905093</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.262075</td>
#       <td>0.283714</td>
#       <td>0.094907</td>
#       <td>0.905093</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.208590</td>
#       <td>0.224398</td>
#       <td>0.077546</td>
#       <td>0.922454</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.166430</td>
#       <td>0.235847</td>
#       <td>0.076389</td>
#       <td>0.923611</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=6.309573450380412e-08, lr_steep=0.0004786300996784121)

# %%
learn.fit_one_cycle(10, lr_max=slice(6e-6, 3e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.142926</td>
#       <td>0.239410</td>
#       <td>0.074074</td>
#       <td>0.925926</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.151444</td>
#       <td>0.297828</td>
#       <td>0.077546</td>
#       <td>0.922454</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.159392</td>
#       <td>0.271520</td>
#       <td>0.078704</td>
#       <td>0.921296</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.152416</td>
#       <td>0.327457</td>
#       <td>0.100694</td>
#       <td>0.899306</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.145006</td>
#       <td>0.272351</td>
#       <td>0.076389</td>
#       <td>0.923611</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.130999</td>
#       <td>0.287836</td>
#       <td>0.079861</td>
#       <td>0.920139</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.111429</td>
#       <td>0.251992</td>
#       <td>0.069444</td>
#       <td>0.930556</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.105603</td>
#       <td>0.252291</td>
#       <td>0.074074</td>
#       <td>0.925926</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.108441</td>
#       <td>0.250632</td>
#       <td>0.069444</td>
#       <td>0.930556</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.099979</td>
#       <td>0.243042</td>
#       <td>0.065972</td>
#       <td>0.934028</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('flowers-resnet18-s2-v2')
# Out:
# Path('C:/Users/NCC/Desktop/thesis/dataset/flowers/models/flowers-resnet18-s2-v2.pth')

# %%
learn.recorder.plot_loss()

# %%
interp1 = ClassificationInterpretation.from_learner(learn)

# %%
interp1.plot_top_losses(9)

# %%
interp1.plot_confusion_matrix(title='Confusion matrix')

# %%
interp1.print_classification_report()
# Out:
#               precision    recall  f1-score   support
#
#        daisy       0.97      0.91      0.94       163
#    dandelion       0.95      0.95      0.95       198
#         rose       0.90      0.96      0.93       162
#    sunflower       0.95      0.96      0.95       146
#        tulip       0.92      0.89      0.90       195
#
#     accuracy                           0.93       864
#    macro avg       0.93      0.94      0.93       864
# weighted avg       0.93      0.93      0.93       864
